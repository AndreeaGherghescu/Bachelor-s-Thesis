# %%
import librosa
from IPython.display import Audio
from scipy import signal
import numpy as np
import glob
from typing import List, Dict, Tuple
from tqdm import tqdm
import pickle
from PIL import Image
from pydub import AudioSegment
from pydub.utils import make_chunks

# %%
#
window_length = 2048
sr = 22050
distance_between_samples = 1 / sr  # in secunde
frequencies = np.fft.fftfreq(window_length, distance_between_samples)[:window_length//2+1]  # valorile pozitive ale frequency bin urilor
num_peaks = 15

def create_constellation(spectrogram):
    # audio asta e spectrograma
    # window_length_seconds = 0.5
    # window_length_samples = int(window_length_seconds * sr)
    # window_length_samples += window_length_samples % 2

    # amount_to_pad = window_length_samples - audio.size % window_length_samples
    # song_input = np.pad(audio, (0, amount_to_pad))

    # frequencies, times, stft = signal.stft(audio, sr, nperseg=window_length_samples, nfft=window_length_samples, return_onesided=True)

    constellation = []
    for time, window in enumerate(spectrogram.T):
        # window is the spectrum from the time-th bin
        # we only want real values
        spectrum = abs(window)  # amplitudini, loudness
        peaks, props = signal.find_peaks(spectrum, prominence=0, distance=200)
        # distance - required minimal horizontal distance (>= 1) in samples between neighbouring peaks. Smaller peaks are removed first until the condition is fulfilled for all remaining peaks.
        # prominence - required prominence of peaks. Either a number, None, an array matching x or a 2-element sequence of the former. The first element is always interpreted as the minimal and the second, if supplied, as the maximal required prominence.

        # Returns
        # peaks - ndarray - indices of peaks in x that satisfy all given conditions.
        # properties - dict - a dictionary containing properties of the returned peaks which were calculated as intermediate results during evaluation of the specified conditions

        n_peaks = min(num_peaks, len(peaks))

        largest_peaks = np.argpartition(props["prominences"], -n_peaks)[-n_peaks:]  # ultimele n_peaks elemente vor fi indexes pt prominences cele mai mari

        for peak in peaks[largest_peaks]:
            frequency = frequencies[peak]  # iau frecventa coresp binului de frecventa in care se incadreaza valoarea peak
            constellation.append([time, frequency])

    return constellation

# plt.scatter(*zip(*constellation_map))
# plt.show()

# %%
# constellation_map = create_constellation(audio, sr)

# %%
def create_hashes (constellation, song_id=None):
    hashes = {}

    upper_frequency = 22050
    frequency_bits = 10

    for index, (first_time, first_freq) in enumerate(constellation):
        for second_time, second_freq in constellation[index : index + 100]:
            difference = second_time - first_time
            if difference <= 1 or difference >= 99:
                continue

            first_binned = first_freq / upper_frequency * (2 ** frequency_bits)
            second_binned = second_freq / upper_frequency * (2 ** frequency_bits)

            hash = int(first_binned) | (int(second_binned) << 10) | (int(difference) << 20)
            hashes[hash] = (first_time, song_id)

    return hashes

# %%
# hashes = create_hashes(constellation_map, 0)
# for i, (hash, (time, _)) in enumerate(hashes.items()):
#     if i > 10:
#         break
#     print(f"Hash {hash} occurred at {time}")

# %%
# songs = songs[:15]
# country_songs = glob.glob('Data/genres_original/country/*.wav')
# country_songs = country_songs[:15]
# pop_songs = glob.glob('Data/genres_original/pop/*.wav')
# pop_songs = pop_songs[:15]
# print(len(songs))
# songs.extend(country_songs)
# songs.extend(pop_songs)

# %%
sr = 22050
songs_indexes = {}
database: Dict[int, List[Tuple[int, int]]] = {}
def load_songs():

    songs = glob.glob('Data/pop+rock+pop_rock+blues_rock/*.[jpPn][npP]*[gG]')
    # Am incarcat spectrogramele din memorie folosind modulul glob.

    for index, filename in enumerate(tqdm(sorted(songs))):
        songs_indexes[index] = filename
        image = Image.open(filename)
        np_image = np.array(image)
        # audio, sr = librosa.load(filename, sr=44100)
        constellation = create_constellation(np_image)
        hashes = create_hashes(constellation, index)

        for hash, time_index_pair in hashes.items():
            if hash not in database:
                database[hash] = []
            database[hash].append(time_index_pair)

load_songs()
# Out:
# 100%|██████████| 402/402 [01:33<00:00,  4.29it/s]

# %%
with open("database.pickle", 'wb') as db:
    pickle.dump(database, db, pickle.HIGHEST_PROTOCOL)
with open("song_index.pickle", 'wb') as songs:
    pickle.dump(songs_indexes, songs, pickle.HIGHEST_PROTOCOL)

# %%
database = pickle.load(open('database.pickle', 'rb'))
song_name_index = pickle.load(open("song_index.pickle", "rb"))

# %%
def find_scores(hashes):
    matches_per_song = {}
    for hash, (sample_time, _) in hashes.items():
        if hash in database:
            matching_occurences = database[hash]
            for source_time, song_index in matching_occurences:
                if song_index not in matches_per_song:
                    matches_per_song[song_index] = []
                matches_per_song[song_index].append((hash, sample_time, source_time))


    # %%
    scores = {}
    for song_index, matches in matches_per_song.items():
        song_scores_by_offset = {}
        for hash, sample_time, source_time in matches:
            delta = source_time - sample_time
            if delta not in song_scores_by_offset:
                song_scores_by_offset[delta] = 0
            song_scores_by_offset[delta] += 1

        max = (0, 0)
        for offset, score in song_scores_by_offset.items():
            if score > max[1]:
                max = (offset, score)

        scores[song_index] = max

    # Sort the scores for the user
    scores = list(sorted(scores.items(), key=lambda x: x[1][1], reverse=True))

    return scores

# audio = AudioSegment.from_file(path)
# duration = len(audio)
# third = duration // 3
# third_audio = audio[:third]
# chunk_length_ms = 1000  # 1 second
# chunks = make_chunks(third_audio, chunk_length_ms)
#
# # Convert each chunk to a NumPy array
# np_audio = np.concatenate([np.array(chunk.get_array_of_samples()) for chunk in chunks], dtype=np.float32)

# %%
path = "Data/pop+drums+guitar_cut0.1.wav"
audio, srr = librosa.load(path)
spect = librosa.feature.melspectrogram(y=audio, sr=sr, fmin=0.)

def print_top_five(new_audio):
    song_constellation = create_constellation(new_audio)
    song_hashes = create_hashes(song_constellation, None)
    scores = find_scores(song_hashes)

    print(f"Total number of songs in the dataset: {len(scores)}")
    print(f"Recording {path.rsplit('/', 1)[1]}:\n")
    for index, (song_id, score) in enumerate(scores):
        song_name = song_name_index[song_id]
        _, filename = song_name.rsplit('/', 1)
        filename = filename.rsplit('.', 1)[0]
        print(f"{index}. {filename}: Score of {score[1]} at {score[0]}")


print_top_five(spect)
# Out:
# Total number of songs in the dataset: 402
# Recording pop+drums+guitar_cut0.1.wav:
#
# 0. pop_spec89: Score of 105 at 842
# 1. pop_spec77: Score of 86 at 844
# 2. pop_rock_spec19: Score of 83 at 802
# 3. pop_spec83: Score of 81 at 827
# 4. pop_spec95: Score of 81 at 748
# 5. pop_rock_spec36: Score of 80 at 844
# 6. pop_rock_spec61: Score of 78 at 700
# 7. rock_spec23: Score of 78 at 903
# 8. pop_spec99: Score of 77 at 840
# 9. pop_rock_spec1: Score of 76 at 842
# 10. blues_rock_spec85: Score of 75 at 821
# 11. pop0_to_rock_feat-matching: Score of 75 at 0
# 12. rock_spec49: Score of 73 at 898
# 13. pop_rock_spec94: Score of 71 at 851
# 14. pop_rock_spec85: Score of 70 at 949
# 15. pop_rock_spec86: Score of 70 at 854
# 16. blues_rock_spec58: Score of 69 at 729
# 17. pop_rock_spec89: Score of 69 at 841
# 18. pop_spec65: Score of 69 at 844
# 19. pop_spec33: Score of 68 at 326
# 20. pop_spec97: Score of 68 at 860
# 21. pop_spec29: Score of 65 at 818
# 22. rock_spec61: Score of 65 at 815
# 23. pop_spec49: Score of 64 at 831
# 24. pop_rock_spec27: Score of 63 at 833
# 25. pop_rock_spec77: Score of 63 at 845
# 26. pop_rock_spec99: Score of 63 at 870
# 27. pop_spec1: Score of 63 at 834
# 28. pop_spec30: Score of 63 at 859
# 29. blues_rock_spec22: Score of 62 at 899
# 30. pop_rock_spec30: Score of 62 at 862
# 31. blues_rock_spec52: Score of 61 at 325
# 32. pop_rock_spec24: Score of 61 at 812
# 33. pop_rock_spec74: Score of 61 at 872
# 34. pop_spec20: Score of 61 at 857
# 35. pop_spec55: Score of 61 at 846
# 36. rock_spec16: Score of 61 at 872
# 37. rock_spec24: Score of 61 at 829
# 38. rock_spec83: Score of 61 at 586
# 39. rock_spec91: Score of 61 at 906
# 40. blues_rock_spec53: Score of 60 at 898
# 41. pop_spec74: Score of 60 at 835
# 42. rock_spec1: Score of 60 at 899
# 43. blues_rock_spec73: Score of 59 at 852
# 44. pop_rock_spec34: Score of 59 at 758
# 45. pop_rock_spec96: Score of 59 at 800
# 46. pop_spec0: Score of 59 at 895
# 47. rock_spec15: Score of 59 at 778
# 48. rock_spec50: Score of 59 at 845
# 49. pop_spec18: Score of 58 at 812
# 50. pop_rock_spec87: Score of 57 at 783
# 51. pop_spec23: Score of 57 at 914
# 52. pop_spec61: Score of 57 at 910
# 53. pop_rock_spec84: Score of 56 at 837
# 54. pop_spec85: Score of 56 at 949
# 55. blues_rock_spec40: Score of 55 at 995
# 56. blues_rock_spec79: Score of 55 at 748
# 57. blues_rock_spec87: Score of 55 at 975
# 58. pop_rock_spec78: Score of 55 at 886
# 59. pop_rock_spec9: Score of 55 at 824
# 60. pop_spec10: Score of 55 at 725
# 61. rock_spec6: Score of 55 at 664
# 62. blues_rock_spec0: Score of 54 at 819
# 63. blues_rock_spec46: Score of 54 at 847
# 64. blues_rock_spec56: Score of 54 at 870
# 65. blues_rock_spec71: Score of 54 at 841
# 66. pop_rock_spec73: Score of 54 at 778
# 67. pop_rock_spec83: Score of 54 at 846
# 68. pop_spec17: Score of 54 at 838
# 69. pop_spec41: Score of 54 at 597
# 70. pop_spec86: Score of 54 at 485
# 71. blues_rock_spec24: Score of 54 at 838
# 72. blues_rock_spec64: Score of 53 at 544
# 73. blues_rock_spec84: Score of 53 at 885
# 74. pop_rock_spec18: Score of 53 at 953
# 75. pop_rock_spec28: Score of 53 at 791
# 76. pop_rock_spec3: Score of 53 at 946
# 77. pop_rock_spec31: Score of 53 at 858
# 78. pop_rock_spec82: Score of 53 at 861
# 79. pop_spec70: Score of 53 at 759
# 80. pop_spec76: Score of 53 at 493
# 81. rock_spec42: Score of 53 at 946
# 82. blues_rock_spec14: Score of 52 at 953
# 83. pop0_to_rock: Score of 52 at 0
# 84. pop_rock_spec0: Score of 52 at 0
# 85. pop_rock_spec69: Score of 52 at 857
# 86. pop_spec42: Score of 52 at 854
# 87. pop_spec96: Score of 52 at 902
# 88. pop_rock_spec46: Score of 51 at 968
# 89. pop_rock_spec7: Score of 51 at 477
# 90. pop_spec12: Score of 51 at 773
# 91. pop_spec26: Score of 51 at 519
# 92. pop_spec27: Score of 51 at 840
# 93. pop_spec43: Score of 51 at 627
# 94. pop_spec68: Score of 51 at 845
# 95. pop_spec72: Score of 51 at 848
# 96. rock_spec2: Score of 51 at 891
# 97. pop_spec47: Score of 50 at 845
# 98. pop_spec59: Score of 50 at 680
# 99. pop_spec78: Score of 50 at 849
# 100. rock_spec25: Score of 50 at 866
# 101. rock_spec4: Score of 50 at 873
# 102. rock_spec55: Score of 50 at 873
# 103. rock_spec80: Score of 50 at 953
# 104. rock_spec88: Score of 50 at 765
# 105. blues_rock_spec3: Score of 49 at 986
# 106. pop_rock_spec33: Score of 49 at 815
# 107. pop_rock_spec42: Score of 49 at 703
# 108. pop_rock_spec58: Score of 49 at 885
# 109. pop_rock_spec75: Score of 49 at 981
# 110. pop_spec21: Score of 49 at 845
# 111. pop_spec25: Score of 49 at 903
# 112. pop_spec28: Score of 49 at 629
# 113. pop_spec88: Score of 49 at 848
# 114. pop_spec90: Score of 49 at 850
# 115. pop_spec94: Score of 49 at 866
# 116. blues_rock_spec23: Score of 49 at 635
# 117. blues_rock_spec8: Score of 48 at 954
# 118. pop_rock_spec23: Score of 48 at 906
# 119. pop_rock_spec39: Score of 48 at 711
# 120. pop_rock_spec41: Score of 48 at 742
# 121. pop_rock_spec81: Score of 48 at 638
# 122. pop_rock_spec92: Score of 48 at 626
# 123. pop_rock_spec95: Score of 48 at 809
# 124. pop_spec2: Score of 48 at 982
# 125. pop_spec32: Score of 48 at 797
# 126. pop_spec62: Score of 48 at 828
# 127. pop_spec73: Score of 48 at 860
# 128. pop_spec9: Score of 48 at 612
# 129. rock_spec44: Score of 48 at 891
# 130. rock_spec74: Score of 48 at 849
# 131. blues_rock_spec27: Score of 48 at 720
# 132. blues_rock_spec17: Score of 47 at 997
# 133. pop_rock_spec10: Score of 47 at 831
# 134. pop_spec19: Score of 47 at 761
# 135. pop_spec36: Score of 47 at 844
# 136. pop_spec51: Score of 47 at 850
# 137. rock_spec63: Score of 47 at 834
# 138. rock_spec70: Score of 47 at 790
# 139. blues_rock_spec5: Score of 47 at 849
# 140. pop_rock_spec29: Score of 46 at 875
# 141. pop_rock_spec52: Score of 46 at 838
# 142. pop_rock_spec88: Score of 46 at 761
# 143. pop_spec24: Score of 46 at 808
# 144. pop_spec31: Score of 46 at 867
# 145. pop_spec66: Score of 46 at 764
# 146. pop_spec84: Score of 46 at 840
# 147. rock_spec32: Score of 46 at 756
# 148. rock_spec7: Score of 46 at 919
# 149. rock_spec22: Score of 46 at 808
# 150. blues_rock_spec25: Score of 45 at 884
# 151. blues_rock_spec47: Score of 45 at 660
# 152. pop_rock_spec49: Score of 45 at 930
# 153. pop_rock_spec51: Score of 45 at 830
# 154. pop_rock_spec56: Score of 45 at 685
# 155. pop_rock_spec65: Score of 45 at 919
# 156. pop_rock_spec67: Score of 45 at 780
# 157. pop_rock_spec71: Score of 45 at 780
# 158. pop_rock_spec90: Score of 45 at 840
# 159. pop_spec22: Score of 45 at 421
# 160. pop_spec58: Score of 45 at 882
# 161. pop_spec67: Score of 45 at 899
# 162. pop_spec71: Score of 45 at 899
# 163. rock_spec27: Score of 45 at 232
# 164. rock_spec51: Score of 45 at 733
# 165. rock_spec21: Score of 45 at 850
# 166. pop_rock_spec17: Score of 44 at 486
# 167. pop_rock_spec44: Score of 44 at 866
# 168. pop_spec87: Score of 44 at 865
# 169. rock_spec62: Score of 44 at 598
# 170. blues_rock_spec12: Score of 43 at 585
# 171. blues_rock_spec16: Score of 43 at 820
# 172. blues_rock_spec51: Score of 43 at 654
# 173. pop_rock_spec16: Score of 43 at 850
# 174. pop_rock_spec45: Score of 43 at 1096
# 175. pop_spec82: Score of 43 at 860
# 176. pop_spec93: Score of 43 at 867
# 177. rock_spec14: Score of 43 at 713
# 178. rock_spec56: Score of 43 at 470
# 179. rock_spec33: Score of 43 at 474
# 180. blues_rock_spec7: Score of 43 at 768
# 181. blues_rock_spec20: Score of 42 at 961
# 182. blues_rock_spec35: Score of 42 at 906
# 183. blues_rock_spec77: Score of 42 at 944
# 184. blues_rock_spec97: Score of 42 at 974
# 185. pop_rock_spec47: Score of 42 at 891
# 186. pop_spec7: Score of 42 at 778
# 187. rock_spec17: Score of 42 at 921
# 188. rock_spec9: Score of 42 at 899
# 189. blues_rock_spec34: Score of 42 at 1020
# 190. blues_rock_spec36: Score of 42 at 920
# 191. blues_rock_spec43: Score of 41 at 998
# 192. blues_rock_spec57: Score of 41 at 836
# 193. blues_rock_spec88: Score of 41 at 941
# 194. blues_rock_spec95: Score of 41 at 880
# 195. pop_rock_spec32: Score of 41 at 898
# 196. pop_rock_spec54: Score of 41 at 844
# 197. pop_rock_spec60: Score of 41 at 844
# 198. pop_rock_spec66: Score of 41 at 847
# 199. pop_spec50: Score of 41 at 641
# 200. pop_spec56: Score of 41 at 910
# 201. rock_spec43: Score of 41 at 872
# 202. rock_spec75: Score of 41 at 973
# 203. blues_rock_spec28: Score of 41 at 972
# 204. blues_rock_spec1: Score of 40 at 586
# 205. blues_rock_spec21: Score of 40 at -46
# 206. pop_rock_spec57: Score of 40 at 839
# 207. pop_rock_spec93: Score of 40 at 809
# 208. pop_spec54: Score of 40 at 315
# 209. pop_spec60: Score of 40 at 315
# 210. pop_spec64: Score of 40 at 273
# 211. pop_spec75: Score of 40 at 950
# 212. pop_spec91: Score of 40 at 926
# 213. rock_spec58: Score of 40 at -120
# 214. rock_spec64: Score of 40 at 775
# 215. rock_spec84: Score of 40 at 870
# 216. blues_rock_spec60: Score of 39 at 774
# 217. blues_rock_spec68: Score of 39 at 842
# 218. blues_rock_spec75: Score of 39 at 803
# 219. pop_rock_spec20: Score of 39 at 782
# 220. pop_rock_spec38: Score of 39 at 842
# 221. pop_rock_spec4: Score of 39 at 882
# 222. pop_rock_spec55: Score of 39 at 853
# 223. pop_spec15: Score of 39 at 318
# 224. pop_spec35: Score of 39 at 852
# 225. pop_spec40: Score of 39 at 425
# 226. pop_spec45: Score of 39 at 776
# 227. pop_spec80: Score of 39 at 846
# 228. rock_spec0: Score of 39 at 689
# 229. rock_spec26: Score of 39 at 206
# 230. rock_spec81: Score of 39 at 790
# 231. blues_rock_spec19: Score of 38 at 847
# 232. blues_rock_spec44: Score of 38 at 982
# 233. blues_rock_spec81: Score of 38 at 432
# 234. blues_rock_spec89: Score of 38 at 1191
# 235. pop_rock_spec76: Score of 38 at 685
# 236. pop_rock_spec79: Score of 38 at 860
# 237. pop_spec16: Score of 38 at 844
# 238. pop_spec34: Score of 38 at 719
# 239. pop_spec8: Score of 38 at 781
# 240. rock_spec85: Score of 38 at 610
# 241. rock_spec93: Score of 38 at 463
# 242. blues_rock_spec31: Score of 38 at 896
# 243. pop_spec79: Score of 38 at 1142
# 244. blues_rock_spec82: Score of 37 at 755
# 245. pop_rock_spec40: Score of 37 at 727
# 246. pop_rock_spec48: Score of 37 at 831
# 247. pop_rock_spec64: Score of 37 at 944
# 248. pop_rock_spec70: Score of 37 at 870
# 249. pop_rock_spec72: Score of 37 at 892
# 250. pop_rock_spec91: Score of 37 at 872
# 251. pop_rock_spec97: Score of 37 at 867
# 252. pop_spec46: Score of 37 at 1103
# 253. pop_spec81: Score of 37 at 685
# 254. pop_spec92: Score of 37 at 869
# 255. rock_spec67: Score of 37 at 931
# 256. rock_spec71: Score of 37 at 826
# 257. rock_spec97: Score of 37 at 333
# 258. blues_rock_spec26: Score of 36 at 774
# 259. blues_rock_spec37: Score of 36 at 979
# 260. blues_rock_spec39: Score of 36 at 117
# 261. blues_rock_spec50: Score of 36 at 929
# 262. blues_rock_spec54: Score of 36 at 193
# 263. blues_rock_spec67: Score of 36 at 778
# 264. blues_rock_spec72: Score of 36 at 613
# 265. pop_rock_spec13: Score of 36 at 653
# 266. pop_rock_spec22: Score of 36 at 887
# 267. pop_rock_spec25: Score of 36 at 902
# 268. pop_spec13: Score of 36 at 346
# 269. pop_spec44: Score of 36 at 900
# 270. pop_spec48: Score of 36 at 854
# 271. rock_spec54: Score of 36 at 705
# 272. rock_spec66: Score of 36 at 800
# 273. rock_spec73: Score of 36 at 681
# 274. blues_rock_spec96: Score of 36 at 959
# 275. rock_spec20: Score of 36 at 903
# 276. blues_rock_spec62: Score of 35 at 787
# 277. pop_rock_spec12: Score of 35 at 772
# 278. pop_rock_spec26: Score of 35 at 838
# 279. pop_rock_spec8: Score of 35 at 815
# 280. pop_rock_spec98: Score of 35 at 684
# 281. pop_spec39: Score of 35 at 970
# 282. rock_spec30: Score of 35 at 715
# 283. rock_spec53: Score of 35 at 815
# 284. rock_spec59: Score of 35 at 977
# 285. rock_spec76: Score of 35 at 823
# 286. blues_rock_spec63: Score of 34 at 946
# 287. blues_rock_spec74: Score of 34 at 433
# 288. blues_rock_spec76: Score of 34 at 743
# 289. blues_rock_spec90: Score of 34 at 848
# 290. pop_rock_spec37: Score of 34 at 886
# 291. pop_rock_spec50: Score of 34 at 623
# 292. pop_spec98: Score of 34 at 799
# 293. rock_spec31: Score of 34 at 219
# 294. rock_spec38: Score of 34 at 689
# 295. rock_spec39: Score of 34 at 637
# 296. rock_spec47: Score of 34 at 675
# 297. rock_spec52: Score of 34 at 836
# 298. rock_spec72: Score of 34 at 1009
# 299. rock_spec89: Score of 34 at 807
# 300. rock_spec99: Score of 34 at 810
# 301. blues_rock_spec48: Score of 33 at 18
# 302. blues_rock_spec66: Score of 33 at 814
# 303. blues_rock_spec80: Score of 33 at 628
# 304. blues_rock_spec83: Score of 33 at 799
# 305. blues_rock_spec94: Score of 33 at 799
# 306. pop_rock_spec2: Score of 33 at 896
# 307. pop_rock_spec43: Score of 33 at 868
# 308. pop_rock_spec62: Score of 33 at 862
# 309. pop_rock_spec68: Score of 33 at 843
# 310. pop_rock_spec80: Score of 33 at 882
# 311. pop_spec14: Score of 33 at 1075
# 312. pop_spec3: Score of 33 at 946
# 313. pop_spec52: Score of 33 at 862
# 314. pop_spec69: Score of 33 at -191
# 315. rock_spec11: Score of 33 at 992
# 316. rock_spec3: Score of 33 at 88
# 317. rock_spec60: Score of 33 at 953
# 318. rock_spec87: Score of 33 at 1080
# 319. rock_spec96: Score of 33 at 586
# 320. blues_rock_spec49: Score of 33 at 395
# 321. pop_rock_spec53: Score of 33 at 849
# 322. pop_spec53: Score of 33 at 1062
# 323. pop_spec11: Score of 33 at -175
# 324. blues_rock_spec6: Score of 32 at 983
# 325. blues_rock_spec98: Score of 32 at 935
# 326. pop_rock_spec5: Score of 32 at 828
# 327. pop_rock_spec6: Score of 32 at 841
# 328. pop_rock_spec63: Score of 32 at 829
# 329. rock_spec18: Score of 32 at 856
# 330. rock_spec34: Score of 32 at 810
# 331. rock_spec36: Score of 32 at 770
# 332. rock_spec78: Score of 32 at 976
# 333. rock_spec90: Score of 32 at -218
# 334. blues_rock_spec33: Score of 32 at 800
# 335. blues_rock_spec69: Score of 32 at 938
# 336. blues_rock_spec9: Score of 32 at 140
# 337. blues_rock_spec2: Score of 31 at 413
# 338. blues_rock_spec38: Score of 31 at 715
# 339. blues_rock_spec41: Score of 31 at 247
# 340. blues_rock_spec59: Score of 31 at 1174
# 341. blues_rock_spec70: Score of 31 at 698
# 342. blues_rock_spec86: Score of 31 at 871
# 343. pop_rock_spec59: Score of 31 at 1162
# 344. pop_spec37: Score of 31 at 434
# 345. pop_spec4: Score of 31 at 883
# 346. rock_spec13: Score of 31 at 1176
# 347. rock_spec65: Score of 31 at 791
# 348. rock_spec79: Score of 31 at 713
# 349. rock_spec8: Score of 31 at 981
# 350. blues_rock_spec30: Score of 31 at 776
# 351. pop_rock_spec11: Score of 31 at 209
# 352. blues_rock_spec11: Score of 30 at 976
# 353. blues_rock_spec18: Score of 30 at 957
# 354. blues_rock_spec45: Score of 30 at 908
# 355. pop_rock_spec35: Score of 30 at 863
# 356. rock_spec94: Score of 30 at 993
# 357. rock_spec45: Score of 30 at 910
# 358. blues_rock_spec10: Score of 29 at 831
# 359. blues_rock_spec78: Score of 29 at 852
# 360. pop_rock_spec21: Score of 29 at 849
# 361. pop_spec57: Score of 29 at 851
# 362. rock_spec12: Score of 29 at 775
# 363. rock_spec37: Score of 29 at 931
# 364. blues_rock_spec4: Score of 29 at 941
# 365. blues_rock_spec55: Score of 28 at 653
# 366. blues_rock_spec91: Score of 28 at 847
# 367. pop_rock_spec14: Score of 28 at 828
# 368. pop_spec5: Score of 28 at 13
# 369. rock_spec19: Score of 28 at 363
# 370. rock_spec29: Score of 28 at 543
# 371. rock_spec35: Score of 28 at 768
# 372. rock_spec57: Score of 28 at 622
# 373. rock_spec68: Score of 28 at 924
# 374. rock_spec95: Score of 28 at 695
# 375. blues_rock_spec13: Score of 28 at 939
# 376. blues_rock_spec61: Score of 27 at 949
# 377. blues_rock_spec93: Score of 27 at 849
# 378. pop_rock_spec15: Score of 27 at 862
# 379. pop_spec38: Score of 27 at 848
# 380. pop_spec6: Score of 27 at 640
# 381. rock_spec82: Score of 27 at 226
# 382. rock_spec86: Score of 27 at 548
# 383. rock_spec69: Score of 27 at 514
# 384. blues_rock_spec15: Score of 26 at 1209
# 385. blues_rock_spec29: Score of 26 at 824
# 386. rock_spec77: Score of 26 at 150
# 387. rock_spec98: Score of 26 at 974
# 388. rock_spec92: Score of 26 at 1150
# 389. blues_rock_spec65: Score of 25 at 295
# 390. blues_rock_spec99: Score of 24 at 860
# 391. pop_spec63: Score of 24 at 71
# 392. rock_spec10: Score of 24 at 831
# 393. rock_spec41: Score of 24 at 753
# 394. rock_spec5: Score of 24 at 916
# 395. blues_rock_spec92: Score of 22 at 378
# 396. rock_spec28: Score of 22 at 855
# 397. rock_spec46: Score of 22 at -41
# 398. blues_rock_spec32: Score of 22 at 988
# 399. blues_rock_spec42: Score of 21 at 983
# 400. rock_spec48: Score of 18 at 1148
# 401. rock_spec40: Score of 15 at 721
