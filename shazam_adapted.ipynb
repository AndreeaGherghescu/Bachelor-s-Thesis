# %%
import librosa
from IPython.display import Audio
from scipy import signal
import numpy as np
import glob
from typing import List, Dict, Tuple
from tqdm import tqdm
import pickle
from PIL import Image
import sounddevice as sd
import soundfile as sf
from scipy.io.wavfile import write
from playsound import playsound
# Out:
# playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.

# %%
window_length = 2048
sr = 22050
distance_between_samples = 1 / sr  # in secunde
frequencies = np.fft.fftfreq(window_length, distance_between_samples)[:window_length//2+1]  # valorile pozitive ale frequency bin urilor
num_peaks = 15

def create_constellation(spectrogram):

    constellation = []
    for time, window in enumerate(spectrogram.T):
        # window is the spectrum from the time-th bin
        # we only want real values
        spectrum = abs(window)  # amplitudini, loudness
        peaks, props = signal.find_peaks(spectrum, prominence=0, distance=200)
        # distance - required minimal horizontal distance (>= 1) in samples between neighbouring peaks. Smaller peaks are removed first until the condition is fulfilled for all remaining peaks.
        # prominence - required prominence of peaks. Either a number, None, an array matching x or a 2-element sequence of the former. The first element is always interpreted as the minimal and the second, if supplied, as the maximal required prominence.

        # Returns
        # peaks - ndarray - indices of peaks in x that satisfy all given conditions.
        # properties - dict - a dictionary containing properties of the returned peaks which were calculated as intermediate results during evaluation of the specified conditions

        n_peaks = min(num_peaks, len(peaks))
        largest_peaks = np.argpartition(props["prominences"], -n_peaks)[-n_peaks:]  # ultimele n_peaks elemente vor fi indexes pt prominences cele mai mari

        for peak in peaks[largest_peaks]:
            frequency = frequencies[peak]  # iau frecventa coresp binului de frecventa in care se incadreaza valoarea peak
            constellation.append([time, frequency])

    return constellation

# %%
def create_hashes (constellation, song_id=None):
    hashes = {}

    upper_frequency = 22050
    frequency_bits = 10

    for index, (first_time, first_freq) in enumerate(constellation):
        for second_time, second_freq in constellation[index : index + 100]:
            difference = second_time - first_time
            if difference <= 1 or difference >= 99:
                continue

            first_binned = first_freq / upper_frequency * (2 ** frequency_bits)
            second_binned = second_freq / upper_frequency * (2 ** frequency_bits)

            hash = int(first_binned) | (int(second_binned) << 10) | (int(difference) << 20)
            hashes[hash] = (first_time, song_id)

    return hashes

# %%
sr = 22050
songs_indexes = {}
database: Dict[int, List[Tuple[int, int]]] = {}
def load_songs():

    songs = glob.glob('Data/pop+rock+pop_rock+blues_rock/*.[jpPn][npP]*[gG]')
    # Am incarcat spectrogramele din memorie folosind modulul glob

    for index, filename in enumerate(tqdm(sorted(songs))):
        songs_indexes[index] = filename
        image = Image.open(filename)
        np_image = np.array(image)
        constellation = create_constellation(np_image)
        hashes = create_hashes(constellation, index)

        for hash, time_index_pair in hashes.items():
            if hash not in database:
                database[hash] = []
            database[hash].append(time_index_pair)

load_songs()
# Out:
# 100%|██████████| 402/402 [01:26<00:00,  4.63it/s]

# %%
with open("database.pickle", 'wb') as db:
    pickle.dump(database, db, pickle.HIGHEST_PROTOCOL)
with open("song_index.pickle", 'wb') as songs:
    pickle.dump(songs_indexes, songs, pickle.HIGHEST_PROTOCOL)

# %%
database = pickle.load(open('database.pickle', 'rb'))
song_name_index = pickle.load(open("song_index.pickle", "rb"))

# %%
def find_scores(hashes):
    matches_per_song = {}
    for hash, (sample_time, _) in hashes.items():
        if hash in database:
            matching_occurences = database[hash]
            for source_time, song_index in matching_occurences:
                if song_index not in matches_per_song:
                    matches_per_song[song_index] = []
                matches_per_song[song_index].append((hash, sample_time, source_time))


    # %%
    scores = {}
    for song_index, matches in matches_per_song.items():
        song_scores_by_offset = {}
        for hash, sample_time, source_time in matches:
            delta = source_time - sample_time
            if delta not in song_scores_by_offset:
                song_scores_by_offset[delta] = 0
            song_scores_by_offset[delta] += 1

        max = (0, 0)
        for offset, score in song_scores_by_offset.items():
            if score > max[1]:
                max = (offset, score)

        scores[song_index] = max

    # Sort the scores for the user
    scores = list(sorted(scores.items(), key=lambda x: x[1][1], reverse=True))

    return scores

# %%
fs = 22050  # Sample rate
seconds = 10  # Duration of recording
path = "Data/test.wav"
myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
sd.wait()  # Wait until recording is finished
write(path, fs, myrecording)  # Save as WAV file

# %%
# Extract data and sampling rate from file
data, fs = sf.read(path, dtype='float32')
sd.play(data, fs)
status = sd.wait()  # Wait until file is done playing

# %%
#path = "Data/pop+drums+guitar_cut0.1.wav"
audio, srr = librosa.load(path)
spect = librosa.feature.melspectrogram(y=audio, sr=sr, fmin=0.)
#spect = librosa.feature.melspectrogram(y=data, sr=sr, fmin=0.)

def print_top_five(new_audio):
    song_constellation = create_constellation(new_audio)
    song_hashes = create_hashes(song_constellation, None)
    scores = find_scores(song_hashes)

    print(f"Total number of songs in the dataset: {len(scores)}")
    print(f"Recording {path.rsplit('/', 1)[1]}:\n")
    for index, (song_id, score) in enumerate(scores):
        song_name = song_name_index[song_id]
        _, filename = song_name.rsplit('/', 1)
        filename = filename.rsplit('.', 1)[0]
        print(f"{index}. {filename}: Score of {score[1]} at {score[0]}")


print_top_five(spect)
# Out:
# Total number of songs in the dataset: 402
# Recording test.wav:
#
# 0. pop_spec35: Score of 91 at 825
# 1. pop_spec1: Score of 89 at 36
# 2. pop_rock_spec24: Score of 71 at 717
# 3. pop_rock_spec35: Score of 68 at 684
# 4. blues_rock_spec68: Score of 63 at 897
# 5. rock_spec85: Score of 62 at 839
# 6. pop_rock_spec4: Score of 61 at 799
# 7. rock_spec31: Score of 60 at 853
# 8. pop_spec26: Score of 60 at 690
# 9. rock_spec23: Score of 60 at 124
# 10. pop_rock_spec1: Score of 59 at 740
# 11. pop_spec11: Score of 59 at 425
# 12. rock_spec53: Score of 58 at 694
# 13. blues_rock_spec27: Score of 55 at 457
# 14. pop_rock_spec44: Score of 55 at 906
# 15. pop_rock_spec18: Score of 55 at 804
# 16. pop_rock_spec23: Score of 54 at 864
# 17. pop_rock_spec37: Score of 54 at 709
# 18. rock_spec62: Score of 54 at 493
# 19. pop_rock_spec62: Score of 53 at 823
# 20. pop_rock_spec34: Score of 53 at 531
# 21. rock_spec26: Score of 53 at 271
# 22. pop_spec5: Score of 52 at 915
# 23. pop_spec41: Score of 52 at 869
# 24. pop_rock_spec68: Score of 51 at 845
# 25. rock_spec90: Score of 51 at 355
# 26. rock_spec81: Score of 50 at 935
# 27. blues_rock_spec67: Score of 50 at 824
# 28. blues_rock_spec65: Score of 49 at 392
# 29. pop_rock_spec28: Score of 48 at 925
# 30. pop_rock_spec90: Score of 48 at 901
# 31. pop_rock_spec20: Score of 48 at 822
# 32. rock_spec84: Score of 48 at 805
# 33. pop_spec94: Score of 48 at 204
# 34. blues_rock_spec82: Score of 47 at 243
# 35. pop_rock_spec19: Score of 47 at 1047
# 36. pop_spec29: Score of 47 at 749
# 37. pop_rock_spec58: Score of 47 at 1008
# 38. pop_rock_spec78: Score of 47 at 391
# 39. pop_rock_spec45: Score of 47 at 914
# 40. pop_spec96: Score of 47 at 567
# 41. blues_rock_spec10: Score of 46 at 837
# 42. pop_spec4: Score of 46 at 803
# 43. rock_spec79: Score of 46 at 710
# 44. pop_spec31: Score of 46 at 655
# 45. blues_rock_spec12: Score of 45 at 764
# 46. blues_rock_spec63: Score of 45 at 434
# 47. blues_rock_spec77: Score of 45 at 754
# 48. blues_rock_spec9: Score of 45 at 833
# 49. pop_rock_spec5: Score of 45 at 915
# 50. pop_rock_spec66: Score of 45 at 1036
# 51. blues_rock_spec73: Score of 45 at 983
# 52. pop_rock_spec47: Score of 45 at 1109
# 53. pop_rock_spec92: Score of 45 at 955
# 54. rock_spec21: Score of 45 at 682
# 55. pop_spec97: Score of 45 at 849
# 56. pop_spec45: Score of 45 at 914
# 57. blues_rock_spec69: Score of 44 at 764
# 58. blues_rock_spec70: Score of 44 at 850
# 59. blues_rock_spec99: Score of 44 at 550
# 60. pop_rock_spec77: Score of 44 at 187
# 61. pop_spec33: Score of 44 at 342
# 62. pop_rock_spec97: Score of 44 at 849
# 63. pop_spec23: Score of 44 at 760
# 64. rock_spec88: Score of 44 at 939
# 65. pop_spec19: Score of 43 at 1037
# 66. pop_spec24: Score of 43 at 1065
# 67. pop_spec9: Score of 43 at 699
# 68. rock_spec57: Score of 43 at 49
# 69. pop_spec37: Score of 42 at 944
# 70. pop_rock_spec25: Score of 42 at 61
# 71. pop_rock_spec33: Score of 42 at 896
# 72. pop_spec55: Score of 42 at 821
# 73. pop_spec58: Score of 42 at 745
# 74. blues_rock_spec71: Score of 41 at 773
# 75. blues_rock_spec15: Score of 41 at 591
# 76. pop_rock_spec94: Score of 41 at 377
# 77. pop_rock_spec29: Score of 40 at 913
# 78. pop_spec34: Score of 40 at 423
# 79. rock_spec58: Score of 40 at 889
# 80. rock_spec24: Score of 40 at 379
# 81. rock_spec20: Score of 40 at 461
# 82. blues_rock_spec7: Score of 39 at 945
# 83. blues_rock_spec80: Score of 39 at 959
# 84. pop_rock_spec31: Score of 39 at 933
# 85. pop_spec22: Score of 39 at 868
# 86. pop_spec89: Score of 39 at 902
# 87. pop_rock_spec91: Score of 39 at 935
# 88. blues_rock_spec62: Score of 39 at 587
# 89. blues_rock_spec72: Score of 39 at 753
# 90. pop_rock_spec67: Score of 38 at 814
# 91. pop_rock_spec71: Score of 38 at 814
# 92. pop_rock_spec9: Score of 38 at 790
# 93. pop_spec64: Score of 38 at 499
# 94. rock_spec82: Score of 38 at 887
# 95. pop_rock_spec30: Score of 38 at 930
# 96. rock_spec43: Score of 38 at 807
# 97. blues_rock_spec60: Score of 37 at 914
# 98. pop_rock_spec73: Score of 37 at 653
# 99. pop_rock_spec76: Score of 37 at 349
# 100. pop_spec95: Score of 37 at 1007
# 101. rock_spec86: Score of 37 at 444
# 102. pop_rock_spec17: Score of 37 at 677
# 103. rock_spec2: Score of 37 at 1001
# 104. pop_rock_spec54: Score of 36 at 310
# 105. pop_rock_spec60: Score of 36 at 310
# 106. pop_rock_spec64: Score of 36 at 476
# 107. pop_rock_spec70: Score of 36 at 1007
# 108. pop_rock_spec72: Score of 36 at 1079
# 109. pop_rock_spec99: Score of 36 at 1074
# 110. pop_rock_spec51: Score of 36 at 944
# 111. pop_rock_spec80: Score of 36 at 7
# 112. pop_spec28: Score of 36 at 878
# 113. blues_rock_spec6: Score of 36 at 793
# 114. rock_spec16: Score of 36 at 1109
# 115. pop_spec98: Score of 36 at 940
# 116. blues_rock_spec4: Score of 36 at 923
# 117. rock_spec7: Score of 36 at 990
# 118. blues_rock_spec20: Score of 35 at 747
# 119. blues_rock_spec58: Score of 35 at 993
# 120. blues_rock_spec78: Score of 35 at 667
# 121. rock_spec89: Score of 35 at 1016
# 122. pop_rock_spec26: Score of 35 at 808
# 123. pop_rock_spec7: Score of 35 at 517
# 124. pop_spec12: Score of 35 at 488
# 125. blues_rock_spec64: Score of 35 at 900
# 126. pop_spec63: Score of 35 at 844
# 127. pop_spec51: Score of 35 at 771
# 128. pop_spec54: Score of 35 at 874
# 129. pop_spec60: Score of 35 at 874
# 130. blues_rock_spec81: Score of 34 at 817
# 131. pop_rock_spec15: Score of 34 at 591
# 132. pop_rock_spec36: Score of 34 at 286
# 133. pop_rock_spec63: Score of 34 at -210
# 134. pop_rock_spec55: Score of 34 at 1030
# 135. blues_rock_spec16: Score of 34 at 181
# 136. rock_spec38: Score of 34 at 1112
# 137. pop_spec70: Score of 34 at 667
# 138. pop_spec93: Score of 34 at 894
# 139. pop_spec39: Score of 34 at 700
# 140. pop_rock_spec41: Score of 34 at 938
# 141. pop_spec46: Score of 34 at 921
# 142. pop_rock_spec22: Score of 33 at 637
# 143. pop_rock_spec57: Score of 33 at 977
# 144. rock_spec41: Score of 33 at 487
# 145. blues_rock_spec53: Score of 33 at 582
# 146. pop_rock_spec93: Score of 33 at 933
# 147. pop_spec30: Score of 33 at 654
# 148. rock_spec22: Score of 33 at 574
# 149. rock_spec80: Score of 33 at 822
# 150. pop_spec20: Score of 33 at 1026
# 151. rock_spec50: Score of 33 at 1087
# 152. blues_rock_spec5: Score of 32 at 891
# 153. blues_rock_spec56: Score of 32 at 431
# 154. blues_rock_spec76: Score of 32 at 67
# 155. pop_rock_spec27: Score of 32 at -76
# 156. pop_rock_spec61: Score of 32 at 855
# 157. pop_rock_spec12: Score of 32 at 521
# 158. pop_spec62: Score of 32 at 672
# 159. pop_rock_spec87: Score of 32 at 709
# 160. pop_rock_spec53: Score of 32 at 903
# 161. blues_rock_spec51: Score of 31 at 871
# 162. pop_rock_spec98: Score of 31 at 539
# 163. pop_spec15: Score of 31 at 882
# 164. pop_spec44: Score of 31 at 1010
# 165. pop_spec72: Score of 31 at 431
# 166. pop_spec78: Score of 31 at 1063
# 167. blues_rock_spec21: Score of 31 at 743
# 168. pop_spec48: Score of 31 at 756
# 169. pop_spec91: Score of 31 at 589
# 170. pop_spec53: Score of 31 at 716
# 171. pop_spec17: Score of 31 at 680
# 172. pop_rock_spec11: Score of 31 at 341
# 173. rock_spec36: Score of 31 at 1130
# 174. rock_spec60: Score of 31 at 341
# 175. blues_rock_spec25: Score of 30 at 990
# 176. pop_rock_spec79: Score of 30 at 925
# 177. pop_rock_spec88: Score of 30 at 739
# 178. pop_spec16: Score of 30 at 70
# 179. pop_spec18: Score of 30 at 8
# 180. pop_spec8: Score of 30 at 697
# 181. pop_spec88: Score of 30 at 495
# 182. rock_spec59: Score of 30 at 605
# 183. pop0_to_rock: Score of 30 at 751
# 184. pop_rock_spec0: Score of 30 at 751
# 185. pop_rock_spec96: Score of 30 at 1048
# 186. pop_spec83: Score of 30 at 1044
# 187. pop_spec77: Score of 30 at 833
# 188. blues_rock_spec13: Score of 30 at 714
# 189. blues_rock_spec19: Score of 30 at 502
# 190. rock_spec54: Score of 30 at -62
# 191. blues_rock_spec84: Score of 29 at 987
# 192. pop_rock_spec46: Score of 29 at 733
# 193. pop_rock_spec56: Score of 29 at -139
# 194. pop_rock_spec8: Score of 29 at 1058
# 195. pop_rock_spec86: Score of 29 at 996
# 196. pop_rock_spec89: Score of 29 at 614
# 197. pop_spec49: Score of 29 at -229
# 198. rock_spec17: Score of 29 at 850
# 199. pop_spec86: Score of 29 at 543
# 200. pop_spec14: Score of 29 at 1016
# 201. rock_spec73: Score of 29 at 1116
# 202. rock_spec83: Score of 29 at 851
# 203. blues_rock_spec2: Score of 28 at 1023
# 204. blues_rock_spec74: Score of 28 at 603
# 205. blues_rock_spec75: Score of 28 at 56
# 206. pop_rock_spec16: Score of 28 at 1052
# 207. pop_rock_spec40: Score of 28 at 802
# 208. pop_rock_spec43: Score of 28 at 692
# 209. pop_rock_spec75: Score of 28 at 1064
# 210. rock_spec40: Score of 28 at 510
# 211. blues_rock_spec0: Score of 28 at -66
# 212. pop_spec27: Score of 28 at 861
# 213. blues_rock_spec59: Score of 28 at 462
# 214. pop_spec80: Score of 28 at 1015
# 215. pop_spec87: Score of 28 at 907
# 216. rock_spec0: Score of 28 at 426
# 217. rock_spec44: Score of 28 at 722
# 218. blues_rock_spec26: Score of 27 at 949
# 219. blues_rock_spec66: Score of 27 at 430
# 220. pop_rock_spec32: Score of 27 at 773
# 221. rock_spec64: Score of 27 at 534
# 222. pop_rock_spec48: Score of 27 at 549
# 223. rock_spec65: Score of 27 at -4
# 224. pop_spec36: Score of 27 at 803
# 225. rock_spec18: Score of 27 at 1112
# 226. pop_rock_spec49: Score of 27 at 883
# 227. pop_rock_spec65: Score of 27 at 1035
# 228. rock_spec6: Score of 27 at 1009
# 229. pop_spec66: Score of 27 at 963
# 230. pop_spec50: Score of 27 at 955
# 231. rock_spec27: Score of 27 at 1007
# 232. rock_spec46: Score of 27 at 86
# 233. blues_rock_spec14: Score of 26 at 305
# 234. blues_rock_spec28: Score of 26 at -13
# 235. blues_rock_spec57: Score of 26 at 1038
# 236. blues_rock_spec79: Score of 26 at 854
# 237. blues_rock_spec90: Score of 26 at 734
# 238. blues_rock_spec96: Score of 26 at 173
# 239. pop_rock_spec69: Score of 26 at 170
# 240. pop_rock_spec95: Score of 26 at 796
# 241. pop_spec42: Score of 26 at 1030
# 242. pop_spec25: Score of 26 at -137
# 243. pop_spec61: Score of 26 at 862
# 244. blues_rock_spec1: Score of 25 at 329
# 245. blues_rock_spec32: Score of 25 at 1101
# 246. blues_rock_spec8: Score of 25 at 503
# 247. pop_rock_spec39: Score of 25 at 658
# 248. pop_rock_spec59: Score of 25 at 42
# 249. pop_spec68: Score of 25 at 804
# 250. rock_spec92: Score of 25 at 892
# 251. pop_rock_spec84: Score of 25 at 259
# 252. blues_rock_spec87: Score of 25 at 772
# 253. pop_rock_spec74: Score of 25 at -22
# 254. rock_spec76: Score of 25 at 953
# 255. pop_spec65: Score of 25 at 1035
# 256. pop_spec92: Score of 25 at 448
# 257. rock_spec93: Score of 25 at 1053
# 258. blues_rock_spec22: Score of 24 at 592
# 259. blues_rock_spec36: Score of 24 at 845
# 260. blues_rock_spec44: Score of 24 at 508
# 261. blues_rock_spec47: Score of 24 at 942
# 262. blues_rock_spec50: Score of 24 at 893
# 263. blues_rock_spec97: Score of 24 at 39
# 264. pop_rock_spec14: Score of 24 at 969
# 265. pop_rock_spec50: Score of 24 at 996
# 266. blues_rock_spec3: Score of 24 at 690
# 267. blues_rock_spec98: Score of 24 at 869
# 268. pop_rock_spec2: Score of 24 at 284
# 269. pop_spec47: Score of 24 at 665
# 270. pop_rock_spec81: Score of 24 at 369
# 271. pop_rock_spec82: Score of 24 at 1144
# 272. rock_spec19: Score of 24 at 61
# 273. rock_spec15: Score of 24 at 995
# 274. blues_rock_spec49: Score of 24 at 682
# 275. pop_spec74: Score of 24 at 1001
# 276. blues_rock_spec11: Score of 23 at 1043
# 277. blues_rock_spec39: Score of 23 at 1207
# 278. blues_rock_spec55: Score of 23 at 264
# 279. pop_rock_spec6: Score of 23 at 1243
# 280. pop_spec40: Score of 23 at 695
# 281. blues_rock_spec18: Score of 23 at 736
# 282. pop0_to_rock_feat-matching: Score of 23 at 277
# 283. pop_rock_spec83: Score of 23 at -192
# 284. rock_spec87: Score of 23 at 694
# 285. pop_rock_spec38: Score of 23 at 1102
# 286. pop_spec73: Score of 23 at 319
# 287. pop_spec59: Score of 23 at -72
# 288. pop_spec0: Score of 23 at 716
# 289. rock_spec51: Score of 23 at 972
# 290. blues_rock_spec37: Score of 22 at 77
# 291. blues_rock_spec43: Score of 22 at 724
# 292. blues_rock_spec83: Score of 22 at 981
# 293. blues_rock_spec88: Score of 22 at 145
# 294. blues_rock_spec94: Score of 22 at 466
# 295. pop_rock_spec3: Score of 22 at 1031
# 296. pop_rock_spec42: Score of 22 at 709
# 297. rock_spec25: Score of 22 at 768
# 298. rock_spec33: Score of 22 at 1092
# 299. blues_rock_spec29: Score of 22 at 1000
# 300. pop_spec32: Score of 22 at 884
# 301. blues_rock_spec54: Score of 22 at 650
# 302. rock_spec67: Score of 22 at 1057
# 303. pop_spec38: Score of 22 at 689
# 304. blues_rock_spec89: Score of 21 at 813
# 305. pop_spec3: Score of 21 at 968
# 306. pop_spec52: Score of 21 at 188
# 307. pop_spec85: Score of 21 at 702
# 308. pop_spec21: Score of 21 at -210
# 309. blues_rock_spec40: Score of 21 at -39
# 310. pop_spec79: Score of 21 at 974
# 311. rock_spec66: Score of 21 at 1105
# 312. blues_rock_spec35: Score of 20 at 1236
# 313. blues_rock_spec95: Score of 20 at 711
# 314. pop_rock_spec10: Score of 20 at 1001
# 315. pop_rock_spec21: Score of 20 at 1114
# 316. pop_rock_spec52: Score of 20 at 1064
# 317. pop_spec57: Score of 20 at 187
# 318. pop_spec7: Score of 20 at 636
# 319. rock_spec32: Score of 20 at 612
# 320. rock_spec56: Score of 20 at 891
# 321. rock_spec71: Score of 20 at 1036
# 322. pop_rock_spec85: Score of 20 at 1034
# 323. rock_spec39: Score of 20 at 669
# 324. rock_spec91: Score of 20 at 933
# 325. pop_spec76: Score of 20 at 601
# 326. rock_spec72: Score of 20 at 1081
# 327. rock_spec55: Score of 20 at 848
# 328. rock_spec49: Score of 20 at 624
# 329. pop_spec99: Score of 20 at 775
# 330. rock_spec10: Score of 20 at 1100
# 331. rock_spec29: Score of 20 at 1162
# 332. rock_spec78: Score of 20 at 638
# 333. blues_rock_spec24: Score of 19 at 787
# 334. blues_rock_spec31: Score of 19 at 971
# 335. rock_spec12: Score of 19 at 1032
# 336. rock_spec37: Score of 19 at 845
# 337. rock_spec42: Score of 19 at 399
# 338. rock_spec48: Score of 19 at 734
# 339. rock_spec68: Score of 19 at 414
# 340. rock_spec77: Score of 19 at 491
# 341. blues_rock_spec38: Score of 19 at 438
# 342. blues_rock_spec85: Score of 19 at 177
# 343. pop_spec2: Score of 19 at 50
# 344. pop_spec90: Score of 19 at 650
# 345. pop_spec56: Score of 19 at 141
# 346. pop_spec84: Score of 19 at 1095
# 347. blues_rock_spec46: Score of 19 at 749
# 348. pop_spec43: Score of 19 at 1122
# 349. rock_spec13: Score of 19 at 1197
# 350. rock_spec63: Score of 19 at 209
# 351. rock_spec9: Score of 19 at -6
# 352. blues_rock_spec93: Score of 18 at 989
# 353. pop_spec10: Score of 18 at 897
# 354. rock_spec8: Score of 18 at 807
# 355. rock_spec97: Score of 18 at 629
# 356. blues_rock_spec17: Score of 18 at 733
# 357. pop_spec67: Score of 18 at 815
# 358. pop_spec71: Score of 18 at 815
# 359. rock_spec30: Score of 18 at 1108
# 360. rock_spec47: Score of 18 at 1114
# 361. blues_rock_spec34: Score of 18 at 1241
# 362. blues_rock_spec33: Score of 18 at 806
# 363. pop_spec75: Score of 18 at 1041
# 364. pop_spec81: Score of 18 at 351
# 365. rock_spec4: Score of 18 at 1144
# 366. rock_spec95: Score of 18 at 652
# 367. blues_rock_spec23: Score of 17 at 172
# 368. blues_rock_spec41: Score of 17 at 843
# 369. pop_spec6: Score of 17 at 1095
# 370. blues_rock_spec30: Score of 17 at 1043
# 371. rock_spec5: Score of 17 at 1025
# 372. rock_spec14: Score of 17 at 928
# 373. pop_rock_spec13: Score of 17 at 895
# 374. rock_spec99: Score of 17 at 611
# 375. blues_rock_spec48: Score of 16 at 633
# 376. blues_rock_spec61: Score of 16 at 961
# 377. blues_rock_spec92: Score of 16 at 1190
# 378. rock_spec34: Score of 16 at 1037
# 379. rock_spec52: Score of 16 at 34
# 380. pop_spec13: Score of 16 at 1035
# 381. pop_spec69: Score of 16 at 595
# 382. blues_rock_spec86: Score of 15 at 386
# 383. rock_spec75: Score of 15 at 740
# 384. blues_rock_spec52: Score of 15 at 388
# 385. blues_rock_spec91: Score of 15 at 735
# 386. rock_spec61: Score of 15 at 755
# 387. blues_rock_spec42: Score of 15 at 1029
# 388. rock_spec1: Score of 15 at 750
# 389. rock_spec11: Score of 15 at 794
# 390. rock_spec45: Score of 15 at 1217
# 391. rock_spec94: Score of 15 at 1191
# 392. rock_spec96: Score of 15 at 632
# 393. rock_spec69: Score of 14 at 853
# 394. rock_spec70: Score of 14 at 915
# 395. pop_spec82: Score of 13 at 565
# 396. rock_spec98: Score of 13 at 1257
# 397. rock_spec74: Score of 12 at 747
# 398. blues_rock_spec45: Score of 11 at 1031
# 399. rock_spec3: Score of 11 at 263
# 400. rock_spec28: Score of 10 at 1207
# 401. rock_spec35: Score of 9 at 902
