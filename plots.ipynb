# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
gen_losses = np.load('TraVeLGAN/noise_feat-matching_gen4layers_20epoci_32x16_lrd=0.00001/TraVeLGAN-gen_losses.npy', allow_pickle=True)
dis_losses = np.load('TraVeLGAN/noise_feat-matching_gen4layers_20epoci_32x16_lrd=0.00001/TraVeLGAN-dis_losses.npy', allow_pickle=True)
plt.plot(gen_losses)
print(len(gen_losses))
# Out:
# 3773
