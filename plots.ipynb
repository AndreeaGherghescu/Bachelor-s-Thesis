# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
gen_losses = np.load('TraVeLGAN/no_smoothing_with_noise_gen4layers_20epoci/TraVeLGAN-gen_losses.npy', allow_pickle=True)
dis_losses = np.load('TraVeLGAN/no_smoothing_with_noise_gen4layers_20epoci/TraVeLGAN-dis_losses.npy', allow_pickle=True)
plt.plot(gen_losses)
print(len(gen_losses))
# Out:
# 4851
