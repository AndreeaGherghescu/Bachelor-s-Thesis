# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
gen_losses = np.load('TraVeLGAN/no_smoothing_with_noise_gen4layers_20epoci/TraVeLGAN-gen_losses.npy', allow_pickle=True)
dis_losses = np.load('TraVeLGAN/no_smoothing_with_noise_gen4layers_20epoci_new/TraVeLGAN-dis_losses.npy', allow_pickle=True)
plt.plot(dis_losses)
print(len(gen_losses))
# Out:
# 4851
